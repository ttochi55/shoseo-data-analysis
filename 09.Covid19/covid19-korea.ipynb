# %% [markdown]
# # COVID-19 2020 대한민국 현황 분석

# %%
import modules.fs as fs

# %%
fs.imshow('./assets/img/covid19_sido_pop.png')

# %%
fs.imshow('./assets/img/covid19_gen_age_case.png')

# %%
fs.imshow('./assets/img/covid19.png')
